# %%
import xml.etree.ElementTree
import nltk
import string
from nltk.corpus import stopwords
from nltk import word_tokenize
e = xml.etree.ElementTree.parse('Laptops_Train_v2.xml').getroot()
with open("sentence_train.txt", "w") as text_file:
    for sent in e:
        print(sent[0].text.lstrip())
        stop = stopwords.words('english') + list(string.punctuation)
        tokens = [i for i in word_tokenize((sent[0].text.lstrip()).lower()) if i not in stop]
        print(nltk.pos_tag(tokens))
        print(tokens)
        print("\n")
        text_file.write(sent[0].text.lstrip())
        text_file.write("\n")
print("--------------------------------------------------------------------------------------------------------")        
with open("sentence_features_train.txt", "w") as text_file:
    for term in e.iter('aspectTerm'):
        print(term.attrib.get('term').lstrip())
        text_file.write(term.attrib.get('term').lstrip())
        text_file.write("\n")
print("--------------------------------------------------------------------------------------------------------")        

e = xml.etree.ElementTree.parse('Laptops_Test_Gold.xml').getroot()
with open("sentence_test.txt", "w") as text_file:
    for sent in e:
        print(sent[0].text.lstrip())
        text_file.write(sent[0].text.lstrip())
        text_file.write("\n")
print("--------------------------------------------------------------------------------------------------------") 
with open("sentence_features_test.txt", "w") as text_file:
    for term in e.iter('aspectTerm'):
        print(term.attrib.get('term').lstrip())
        text_file.write(term.attrib.get('term').lstrip())
        text_file.write("\n")
print("--------------------------------------------------------------------------------------------------------")
# Out:
# I charge it at night and skip taking the cord with me because of the good battery life.
# [('charge', 'NN'), ('night', 'NN'), ('skip', 'NN'), ('taking', 'VBG'), ('cord', 'NN'), ('good', 'JJ'), ('battery', 'NN'), ('life', 'NN')]
# ['charge', 'night', 'skip', 'taking', 'cord', 'good', 'battery', 'life']
#
#
# I bought a HP Pavilion DV4-1222nr laptop and have had so many problems with the computer.
# [('bought', 'VBN'), ('hp', 'JJ'), ('pavilion', 'NN'), ('dv4-1222nr', 'JJ'), ('laptop', 'JJ'), ('many', 'JJ'), ('problems', 'NNS'), ('computer', 'NN')]
# ['bought', 'hp', 'pavilion', 'dv4-1222nr', 'laptop', 'many', 'problems', 'computer']
#
#
# The tech guy then said the service center does not do 1-to-1 exchange and I have to direct my concern to the "sales" team, which is the retail shop which I bought my netbook from.
# [('tech', 'NN'), ('guy', 'NN'), ('said', 'VBD'), ('service', 'NN'), ('center', 'NN'), ('1-to-1', 'JJ'), ('exchange', 'NN'), ('direct', 'JJ'), ('concern', 'NN'), ('``', '``'), ('sales', 'NNS'), ("''", "''"), ('team', 'NN'), ('retail', 'NN'), ('shop', 'NN'), ('bought', 'VBD'), ('netbook', 'NN')]
# ['tech', 'guy', 'said', 'service', 'center', '1-to-1', 'exchange', 'direct', 'concern', '``', 'sales', "''", 'team', 'retail', 'shop', 'bought', 'netbook']
#
#
# I investigated netbooks and saw the Toshiba NB305-N410BL.
# [('investigated', 'VBN'), ('netbooks', 'NNS'), ('saw', 'VBD'), ('toshiba', 'JJ'), ('nb305-n410bl', 'JJ')]
# ['investigated', 'netbooks', 'saw', 'toshiba', 'nb305-n410bl']
#
#
# The other day I had a presentation to do for a seminar at a large conference in town- lots of people, little time to prep and have to set up a computer to a projector, etc.
# [('day', 'NN'), ('presentation', 'NN'), ('seminar', 'NN'), ('large', 'JJ'), ('conference', 'NN'), ('town-', 'JJ'), ('lots', 'NNS'), ('people', 'NNS'), ('little', 'JJ'), ('time', 'NN'), ('prep', 'NN'), ('set', 'VBN'), ('computer', 'NN'), ('projector', 'NN'), ('etc', 'NN')]
# ['day', 'presentation', 'seminar', 'large', 'conference', 'town-', 'lots', 'people', 'little', 'time', 'prep', 'set', 'computer', 'projector', 'etc']
#
#
# it is of high quality, has a killer GUI, is extremely stable, is highly expandable, is bundled with lots of very good applications, is easy to use, and is absolutely gorgeous.
# [('high', 'JJ'), ('quality', 'NN'), ('killer', 'NN'), ('gui', 'NN'), ('extremely', 'RB'), ('stable', 'JJ'), ('highly', 'RB'), ('expandable', 'JJ'), ('bundled', 'VBN'), ('lots', 'NNS'), ('good', 'JJ'), ('applications', 'NNS'), ('easy', 'JJ'), ('use', 'NN'), ('absolutely', 'RB'), ('gorgeous', 'JJ')]
# ['high', 'quality', 'killer', 'gui', 'extremely', 'stable', 'highly', 'expandable', 'bundled', 'lots', 'good', 'applications', 'easy', 'use', 'absolutely', 'gorgeous']
#
#
# Easy to start up and does not overheat as much as other laptops.
# [('easy', 'JJ'), ('start', 'VB'), ('overheat', 'NN'), ('much', 'JJ'), ('laptops', 'NNS')]
# ['easy', 'start', 'overheat', 'much', 'laptops']
#
#
# Sad very SAD.
# [('sad', 'JJ'), ('sad', 'NN')]
# ['sad', 'sad']
#
#
# I even got my teenage son one, because of the features that it offers, like, iChat, Photobooth, garage band and more!
# [('even', 'RB'), ('got', 'VBD'), ('teenage', 'JJ'), ('son', 'NN'), ('one', 'CD'), ('features', 'VBZ'), ('offers', 'NNS'), ('like', 'IN'), ('ichat', 'DT'), ('photobooth', 'JJ'), ('garage', 'NN'), ('band', 'NN')]
# ['even', 'got', 'teenage', 'son', 'one', 'features', 'offers', 'like', 'ichat', 'photobooth', 'garage', 'band']
#
#
# Needless to say a PC that can't support a cell phone is less than useless!
# [('needless', 'JJ'), ('say', 'VBP'), ('pc', 'NN'), ('ca', 'MD'), ("n't", 'RB'), ('support', 'VB'), ('cell', 'VB'), ('phone', 'NN'), ('less', 'JJR'), ('useless', 'JJ')]
# ['needless', 'say', 'pc', 'ca', "n't", 'support', 'cell', 'phone', 'less', 'useless']
#
#
# Great laptop that offers many great features!
# [('great', 'JJ'), ('laptop', 'JJ'), ('offers', 'NNS'), ('many', 'JJ'), ('great', 'JJ'), ('features', 'NNS')]
# ['great', 'laptop', 'offers', 'many', 'great', 'features']
#
#
# they have done absolutely nothing to fix the computer problem.
# [('done', 'VBN'), ('absolutely', 'RB'), ('nothing', 'NN'), ('fix', 'JJ'), ('computer', 'NN'), ('problem', 'NN')]
# ['done', 'absolutely', 'nothing', 'fix', 'computer', 'problem']
#
#
# One night I turned the freaking thing off after using it, the next day I turn it on, no GUI, screen all dark, power light steady, hard drive light steady and not flashing as it usually does.
# [('one', 'CD'), ('night', 'NN'), ('turned', 'VBD'), ('freaking', 'JJ'), ('thing', 'NN'), ('using', 'VBG'), ('next', 'JJ'), ('day', 'NN'), ('turn', 'VB'), ('gui', 'JJ'), ('screen', 'NN'), ('dark', 'JJ'), ('power', 'NN'), ('light', 'VBD'), ('steady', 'JJ'), ('hard', 'JJ'), ('drive', 'NN'), ('light', 'NN'), ('steady', 'JJ'), ('flashing', 'NN'), ('usually', 'RB')]
# ['one', 'night', 'turned', 'freaking', 'thing', 'using', 'next', 'day', 'turn', 'gui', 'screen', 'dark', 'power', 'light', 'steady', 'hard', 'drive', 'light', 'steady', 'flashing', 'usually']
#
#
# Still pretty pricey, but I've been putting off money for a while as a little Macbook Fund, and finally got to use it.
# [('still', 'RB'), ('pretty', 'RB'), ('pricey', 'JJ'), ("'ve", 'VBP'), ('putting', 'VBG'), ('money', 'NN'), ('little', 'JJ'), ('macbook', 'NN'), ('fund', 'NN'), ('finally', 'RB'), ('got', 'VBD'), ('use', 'NN')]
# ['still', 'pretty', 'pricey', "'ve", 'putting', 'money', 'little', 'macbook', 'fund', 'finally', 'got', 'use']
#
#
# I took it back for an Asus and same thing- blue screen which required me to remove the battery to reset.
# [('took', 'VBD'), ('back', 'RP'), ('asus', 'JJ'), ('thing-', 'NN'), ('blue', 'JJ'), ('screen', 'NN'), ('required', 'VBN'), ('remove', 'VB'), ('battery', 'NN'), ('reset', 'NN')]
# ['took', 'back', 'asus', 'thing-', 'blue', 'screen', 'required', 'remove', 'battery', 'reset']
#
#
# In the shop, these MacBooks are encased in a soft rubber enclosure - so you will never know about the razor edge until you buy it, get it home, break the seal and use it (very clever con).
# [('shop', 'NN'), ('macbooks', 'NNS'), ('encased', 'VBD'), ('soft', 'JJ'), ('rubber', 'NN'), ('enclosure', 'NN'), ('never', 'RB'), ('know', 'VBP'), ('razor', 'NN'), ('edge', 'NN'), ('buy', 'VBP'), ('get', 'VBP'), ('home', 'NN'), ('break', 'NN'), ('seal', 'NN'), ('use', 'NN'), ('clever', 'NN'), ('con', 'NN')]
# ['shop', 'macbooks', 'encased', 'soft', 'rubber', 'enclosure', 'never', 'know', 'razor', 'edge', 'buy', 'get', 'home', 'break', 'seal', 'use', 'clever', 'con']
#
#
# However, the multi-touch gestures and large tracking area make having an external mouse unnecessary (unless you're gaming).
# [('however', 'RB'), ('multi-touch', 'JJ'), ('gestures', 'NNS'), ('large', 'JJ'), ('tracking', 'VBG'), ('area', 'NN'), ('make', 'VBP'), ('external', 'JJ'), ('mouse', 'NN'), ('unnecessary', 'JJ'), ('unless', 'IN'), ("'re", 'VBP'), ('gaming', 'VBG')]
# ['however', 'multi-touch', 'gestures', 'large', 'tracking', 'area', 'make', 'external', 'mouse', 'unnecessary', 'unless', "'re", 'gaming']
#
#
# Plus it is small and reasonably light so I can take it with me to and from work.
# [('plus', 'CC'), ('small', 'JJ'), ('reasonably', 'RB'), ('light', 'JJ'), ('take', 'VBP'), ('work', 'NN')]
# ['plus', 'small', 'reasonably', 'light', 'take', 'work']
#
#
# I HATE this one.
# [('hate', 'NN'), ('one', 'CD')]
# ['hate', 'one']
#
#
# They were totally unconcerned that the computer was not correctly repaired in the first place.
# [('totally', 'RB'), ('unconcerned', 'JJ'), ('computer', 'NN'), ('correctly', 'RB'), ('repaired', 'VBD'), ('first', 'JJ'), ('place', 'NN')]
# ['totally', 'unconcerned', 'computer', 'correctly', 'repaired', 'first', 'place']
#
#
# Toshiba does not send any one out unless you have paid extra to have the on site repair done.
# [('toshiba', 'JJ'), ('send', 'VBP'), ('one', 'CD'), ('unless', 'IN'), ('paid', 'VBN'), ('extra', 'JJ'), ('site', 'NN'), ('repair', 'NN'), ('done', 'VBN')]
# ['toshiba', 'send', 'one', 'unless', 'paid', 'extra', 'site', 'repair', 'done']
#
#
# Oh, boy!
# [('oh', 'UH'), ('boy', 'NN')]
# ['oh', 'boy']
#
#
# But while this is one big advantage (as you may know from the company s recent commercials) there are other things to consider before going with Apple.
# [('one', 'CD'), ('big', 'JJ'), ('advantage', 'NN'), ('may', 'MD'), ('know', 'VB'), ('company', 'NN'), ('recent', 'JJ'), ('commercials', 'NNS'), ('things', 'NNS'), ('consider', 'VBP'), ('going', 'VBG'), ('apple', 'NN')]
# ['one', 'big', 'advantage', 'may', 'know', 'company', 'recent', 'commercials', 'things', 'consider', 'going', 'apple']
#
#
# I love the way the entire suite of software works together.
# [('love', 'VB'), ('way', 'NN'), ('entire', 'JJ'), ('suite', 'NN'), ('software', 'NN'), ('works', 'VBZ'), ('together', 'RB')]
# ['love', 'way', 'entire', 'suite', 'software', 'works', 'together']
#
#
# The speed is incredible and I am more than satisfied.
# [('speed', 'NN'), ('incredible', 'JJ'), ('satisfied', 'VBD')]
# ['speed', 'incredible', 'satisfied']
#
#
# on the bright side at least I wasn't without my laptop for long this time!
# [('bright', 'JJ'), ('side', 'NN'), ('least', 'VBP'), ("n't", 'RB'), ('without', 'IN'), ('laptop', 'VB'), ('long', 'JJ'), ('time', 'NN')]
# ['bright', 'side', 'least', "n't", 'without', 'laptop', 'long', 'time']
#
#
# This laptop meets every expectation and Windows 7 is great!
# [('laptop', 'JJ'), ('meets', 'NNS'), ('every', 'DT'), ('expectation', 'NN'), ('windows', 'VBZ'), ('7', 'CD'), ('great', 'JJ')]
# ['laptop', 'meets', 'every', 'expectation', 'windows', '7', 'great']
#
#
# That's how frustrating it was.
# [("'s", 'POS'), ('frustrating', 'NN')]
# ["'s", 'frustrating']
#
#
# I can barely use any usb devices because they will not stay connected properly.
# [('barely', 'RB'), ('use', 'NN'), ('usb', 'JJ'), ('devices', 'NNS'), ('stay', 'VBP'), ('connected', 'VBN'), ('properly', 'RB')]
# ['barely', 'use', 'usb', 'devices', 'stay', 'connected', 'properly']
#
#
# The one down side to it is that when I play a certin game on here, it tends to freeze up sometimes, but thats the only bad thing about this computer.
# [('one', 'CD'), ('side', 'NN'), ('play', 'NN'), ('certin', 'NN'), ('game', 'NN'), ('tends', 'VBZ'), ('freeze', 'JJ'), ('sometimes', 'RB'), ('thats', 'VBZ'), ('bad', 'JJ'), ('thing', 'NN'), ('computer', 'NN')]
# ['one', 'side', 'play', 'certin', 'game', 'tends', 'freeze', 'sometimes', 'thats', 'bad', 'thing', 'computer']
#
#
# -No backlit keyboard, but not an issue for me.
# [('-no', 'JJ'), ('backlit', 'JJ'), ('keyboard', 'NN'), ('issue', 'NN')]
# ['-no', 'backlit', 'keyboard', 'issue']
#
#
# When I finally had everything running with all my software installed I plugged in my droid to recharge and the system crashed.
# [('finally', 'RB'), ('everything', 'NN'), ('running', 'VBG'), ('software', 'NN'), ('installed', 'VBD'), ('plugged', 'VBN'), ('droid', 'RB'), ('recharge', 'NN'), ('system', 'NN'), ('crashed', 'VBD')]
# ['finally', 'everything', 'running', 'software', 'installed', 'plugged', 'droid', 'recharge', 'system', 'crashed']
#
#
# I can't even turn it off.
# [('ca', 'MD'), ("n't", 'RB'), ('even', 'RB'), ('turn', 'VB')]
# ['ca', "n't", 'even', 'turn']
#
#
# One suggestion I do have, is to not bother getting Microsoft office for the mac expecting it will work just like you knew it to on a PC.
# [('one', 'CD'), ('suggestion', 'NN'), ('bother', 'IN'), ('getting', 'VBG'), ('microsoft', 'JJ'), ('office', 'NN'), ('mac', 'NN'), ('expecting', 'VBG'), ('work', 'NN'), ('like', 'IN'), ('knew', 'JJ'), ('pc', 'NN')]
# ['one', 'suggestion', 'bother', 'getting', 'microsoft', 'office', 'mac', 'expecting', 'work', 'like', 'knew', 'pc']
#
#
# Pairing it with an iPhone is a pure pleasure - talk about painless syncing - used to take me forever - now it's a snap.
# [('pairing', 'VBG'), ('iphone', 'NN'), ('pure', 'NN'), ('pleasure', 'NN'), ('talk', 'NN'), ('painless', 'IN'), ('syncing', 'VBG'), ('used', 'VBN'), ('take', 'VB'), ('forever', 'NN'), ("'s", 'POS'), ('snap', 'NN')]
# ['pairing', 'iphone', 'pure', 'pleasure', 'talk', 'painless', 'syncing', 'used', 'take', 'forever', "'s", 'snap']
#
#
# I shopped around before buying.
# [('shopped', 'VBN'), ('around', 'IN'), ('buying', 'VBG')]
# ['shopped', 'around', 'buying']
#
#
# I also got the added bonus of a 30" HD Monitor, which really helps to extend my screen and keep my eyes fresh!
# [('also', 'RB'), ('got', 'VBD'), ('added', 'JJ'), ('bonus', 'NN'), ('30', 'CD'), ("''", "''"), ('hd', 'NN'), ('monitor', 'NN'), ('really', 'RB'), ('helps', 'VBZ'), ('extend', 'VB'), ('screen', 'JJ'), ('keep', 'VB'), ('eyes', 'NNS'), ('fresh', 'JJ')]
# ['also', 'got', 'added', 'bonus', '30', "''", 'hd', 'monitor', 'really', 'helps', 'extend', 'screen', 'keep', 'eyes', 'fresh']
#
#
# Would do business again.
# [('would', 'MD'), ('business', 'NN')]
# ['would', 'business']
#
#
# The machine is slow to boot up and occasionally crashes completely.
# [('machine', 'NN'), ('slow', 'JJ'), ('boot', 'NN'), ('occasionally', 'RB'), ('crashes', 'NNS'), ('completely', 'RB')]
# ['machine', 'slow', 'boot', 'occasionally', 'crashes', 'completely']
#
#
# After paying several hundred dollars for this service, it is frustrating that you cannot get help after hours.
# [('paying', 'VBG'), ('several', 'JJ'), ('hundred', 'CD'), ('dollars', 'NNS'), ('service', 'NN'), ('frustrating', 'VBG'), ('get', 'VB'), ('help', 'NN'), ('hours', 'NNS')]
# ['paying', 'several', 'hundred', 'dollars', 'service', 'frustrating', 'get', 'help', 'hours']
#
#
# I have had the luxury (sarcasm) of owning 2 of these laptops.
# [('luxury', 'NN'), ('sarcasm', 'VBD'), ('owning', 'VBG'), ('2', 'CD'), ('laptops', 'NNS')]
# ['luxury', 'sarcasm', 'owning', '2', 'laptops']
#
#
# What a waste.
# [('waste', 'NN')]
# ['waste']
#
#
# It was a total Dhell experience that I will never repeat.
# [('total', 'JJ'), ('dhell', 'NN'), ('experience', 'NN'), ('never', 'RB'), ('repeat', 'NN')]
# ['total', 'dhell', 'experience', 'never', 'repeat']
#
#
# There are a few flaws as well that I noticed.
# [('flaws', 'RB'), ('well', 'RB'), ('noticed', 'VBN')]
# ['flaws', 'well', 'noticed']
#
#
# Completely worth every single penny dime and nickel.
# [('completely', 'RB'), ('worth', 'JJ'), ('every', 'DT'), ('single', 'JJ'), ('penny', 'NN'), ('dime', 'NN'), ('nickel', 'NN')]
# ['completely', 'worth', 'every', 'single', 'penny', 'dime', 'nickel']
#
#
# I tried to upgrade it to a newer version a couple of months ago and I still have the same problem.
# [('tried', 'VBN'), ('upgrade', 'JJ'), ('newer', 'JJR'), ('version', 'NN'), ('couple', 'JJ'), ('months', 'NNS'), ('ago', 'RB'), ('still', 'RB'), ('problem', 'NN')]
# ['tried', 'upgrade', 'newer', 'version', 'couple', 'months', 'ago', 'still', 'problem']
#
#
# I did have to replace the battery once, but that was only a couple months ago and it's been working perfect ever since.
# [('replace', 'VB'), ('battery', 'JJ'), ('couple', 'NN'), ('months', 'NNS'), ('ago', 'RB'), ("'s", 'POS'), ('working', 'VBG'), ('perfect', 'JJ'), ('ever', 'RB'), ('since', 'IN')]
# ['replace', 'battery', 'couple', 'months', 'ago', "'s", 'working', 'perfect', 'ever', 'since']
#
#
# :) In the past four years I've had it I have never once gotten a virus.
# [('past', 'IN'), ('four', 'CD'), ('years', 'NNS'), ("'ve", 'VBP'), ('never', 'RB'), ('gotten', 'VBN'), ('virus', 'NN')]
# ['past', 'four', 'years', "'ve", 'never', 'gotten', 'virus']
#
#
# I love the operating system and the preloaded software.
# [('love', 'VB'), ('operating', 'NN'), ('system', 'NN'), ('preloaded', 'VBD'), ('software', 'NN')]
# ['love', 'operating', 'system', 'preloaded', 'software']
#
#
# They were great in handling this problem, and I'm looking forward in purchasing additonal products from them in the future.
# [('great', 'JJ'), ('handling', 'VBG'), ('problem', 'NN'), ("'m", 'VBP'), ('looking', 'VBG'), ('forward', 'RB'), ('purchasing', 'VBG'), ('additonal', 'JJ'), ('products', 'NNS'), ('future', 'JJ')]
# ['great', 'handling', 'problem', "'m", 'looking', 'forward', 'purchasing', 'additonal', 'products', 'future']
#
#
# I've tried going back to XL but there still problems.
# [("'ve", 'VBP'), ('tried', 'VBN'), ('going', 'VBG'), ('back', 'RB'), ('xl', 'NNP'), ('still', 'RB'), ('problems', 'NNS')]
# ["'ve", 'tried', 'going', 'back', 'xl', 'still', 'problems']
#
#
# The best thing about this laptop is the price along with some of the newer features.
# [('best', 'JJS'), ('thing', 'NN'), ('laptop', 'JJ'), ('price', 'NN'), ('along', 'IN'), ('newer', 'JJR'), ('features', 'NNS')]
# ['best', 'thing', 'laptop', 'price', 'along', 'newer', 'features']
#
#
# After numerous attempts of trying (including setting the clock in BIOS setup directly), I gave up(I am a techie).
# [('numerous', 'JJ'), ('attempts', 'NNS'), ('trying', 'VBG'), ('including', 'VBG'), ('setting', 'VBG'), ('clock', 'NN'), ('bios', 'NNS'), ('setup', 'VBP'), ('directly', 'RB'), ('gave', 'VBD'), ('techie', 'NN')]
# ['numerous', 'attempts', 'trying', 'including', 'setting', 'clock', 'bios', 'setup', 'directly', 'gave', 'techie']
#
#
# YOU WILL NOT BE ABLE TO TALK TO AN AMERICAN WARRANTY SERVICE IS OUT OF COUNTRY.
# [('able', 'JJ'), ('talk', 'NN'), ('american', 'JJ'), ('warranty', 'NN'), ('service', 'NN'), ('country', 'NN')]
# ['able', 'talk', 'american', 'warranty', 'service', 'country']
#
#
# But it may be potentially hundreds or thousands in the near future.
# [('may', 'MD'), ('potentially', 'RB'), ('hundreds', 'VB'), ('thousands', 'NNS'), ('near', 'IN'), ('future', 'JJ')]
# ['may', 'potentially', 'hundreds', 'thousands', 'near', 'future']
#
#
# Has met or exceeded my needs for a compact travel device.
# [('met', 'NN'), ('exceeded', 'VBD'), ('needs', 'NNS'), ('compact', 'JJ'), ('travel', 'NN'), ('device', 'NN')]
# ['met', 'exceeded', 'needs', 'compact', 'travel', 'device']
#
#
# but now i have realized its a problem with this brand.
# [('realized', 'VBN'), ('problem', 'NN'), ('brand', 'NN')]
# ['realized', 'problem', 'brand']
#
#
# It cannot save the correct date and time I set.
# [('save', 'VB'), ('correct', 'JJ'), ('date', 'NN'), ('time', 'NN'), ('set', 'VBN')]
# ['save', 'correct', 'date', 'time', 'set']
#
#
# I sent it back to Toshiba twice they covered it under the  warranty.
# [('sent', 'VBN'), ('back', 'RP'), ('toshiba', 'JJ'), ('twice', 'RB'), ('covered', 'VBD'), ('warranty', 'NN')]
# ['sent', 'back', 'toshiba', 'twice', 'covered', 'warranty']
#
#
# And this isn't just my one experine.
# [("n't", 'RB'), ('one', 'CD'), ('experine', 'NN')]
# ["n't", 'one', 'experine']
#
#
# They sent me a replacement part and without informing me are requiring that I return it within 15 days or contact them and let them know the broken part will be returned later.
# [('sent', 'VBN'), ('replacement', 'NN'), ('part', 'NN'), ('without', 'IN'), ('informing', 'VBG'), ('requiring', 'VBG'), ('return', 'NN'), ('within', 'IN'), ('15', 'CD'), ('days', 'NNS'), ('contact', 'JJ'), ('let', 'NN'), ('know', 'VB'), ('broken', 'JJ'), ('part', 'NN'), ('returned', 'VBD'), ('later', 'RB')]
# ['sent', 'replacement', 'part', 'without', 'informing', 'requiring', 'return', 'within', '15', 'days', 'contact', 'let', 'know', 'broken', 'part', 'returned', 'later']
#
#
# I was looking for a mac which is portable and has all the features that I was looking for.
# [('looking', 'VBG'), ('mac', 'NN'), ('portable', 'JJ'), ('features', 'NNS'), ('looking', 'VBG')]
# ['looking', 'mac', 'portable', 'features', 'looking']
#
#
# I would highly recommend this one to my friends
# [('would', 'MD'), ('highly', 'RB'), ('recommend', 'VB'), ('one', 'CD'), ('friends', 'NNS')]
# ['would', 'highly', 'recommend', 'one', 'friends']
#
#
# I honestly love my mac, thats why I am a self proclaimed mac addict.
# [('honestly', 'RB'), ('love', 'VB'), ('mac', 'NN'), ('thats', 'NNS'), ('self', 'VBP'), ('proclaimed', 'VBN'), ('mac', 'NNS'), ('addict', 'VBP')]
# ['honestly', 'love', 'mac', 'thats', 'self', 'proclaimed', 'mac', 'addict']
#
#
# And these are some reasons you should get a macbook pro.
# [('reasons', 'NNS'), ('get', 'VBP'), ('macbook', 'JJ'), ('pro', 'FW')]
# ['reasons', 'get', 'macbook', 'pro']
#
#
# Also kinda loud when the fan was running.
# [('also', 'RB'), ('kinda', 'VBZ'), ('loud', 'JJ'), ('fan', 'NN'), ('running', 'VBG')]
# ['also', 'kinda', 'loud', 'fan', 'running']
#
#
# In desparation, I called their Customer Service number and was told that my warranty had expired (2 days old) and that the priviledge of talking to a technician would cost me ("have your credit card ready").
# [('desparation', 'NN'), ('called', 'VBN'), ('customer', 'NN'), ('service', 'NN'), ('number', 'NN'), ('told', 'VBD'), ('warranty', 'NN'), ('expired', 'VBD'), ('2', 'CD'), ('days', 'NNS'), ('old', 'JJ'), ('priviledge', 'NN'), ('talking', 'VBG'), ('technician', 'JJ'), ('would', 'MD'), ('cost', 'VB'), ('``', '``'), ('credit', 'NN'), ('card', 'NN'), ('ready', 'JJ'), ("''", "''")]
# ['desparation', 'called', 'customer', 'service', 'number', 'told', 'warranty', 'expired', '2', 'days', 'old', 'priviledge', 'talking', 'technician', 'would', 'cost', '``', 'credit', 'card', 'ready', "''"]
#
#
# I purchased this laptop while on a business trip to keep up with my email.
# [('purchased', 'VBN'), ('laptop', 'JJ'), ('business', 'NN'), ('trip', 'NN'), ('keep', 'NN'), ('email', 'NN')]
# ['purchased', 'laptop', 'business', 'trip', 'keep', 'email']
#
#
# There also seemed to be a problem with the hard disc as certain times windows loads but claims to not be able to find any drivers or files.
# [('also', 'RB'), ('seemed', 'VBD'), ('problem', 'NN'), ('hard', 'JJ'), ('disc', 'NN'), ('certain', 'JJ'), ('times', 'NNS'), ('windows', 'VBP'), ('loads', 'NNS'), ('claims', 'NNS'), ('able', 'JJ'), ('find', 'VBP'), ('drivers', 'NNS'), ('files', 'NNS')]
# ['also', 'seemed', 'problem', 'hard', 'disc', 'certain', 'times', 'windows', 'loads', 'claims', 'able', 'find', 'drivers', 'files']
#
#
# Drivers updated ok but the BIOS update froze the system up and the computer shut down.
# [('drivers', 'NNS'), ('updated', 'VBD'), ('ok', 'JJ'), ('bios', 'NNS'), ('update', 'VBP'), ('froze', 'NN'), ('system', 'NN'), ('computer', 'NN'), ('shut', 'NN')]
# ['drivers', 'updated', 'ok', 'bios', 'update', 'froze', 'system', 'computer', 'shut']
#
#
# -they lost my laptop for a month
# [('-they', 'NN'), ('lost', 'VBD'), ('laptop', 'JJ'), ('month', 'NN')]
# ['-they', 'lost', 'laptop', 'month']
#
#
# Spent 2 hours on phone with HP Technical Support.
# [('spent', 'NN'), ('2', 'CD'), ('hours', 'NNS'), ('phone', 'NN'), ('hp', 'VBD'), ('technical', 'JJ'), ('support', 'NN')]
# ['spent', '2', 'hours', 'phone', 'hp', 'technical', 'support']
#
#
# This is my second laptop,and it is head and shoulders above my first.
# [('second', 'JJ'), ('laptop', 'JJ'), ('head', 'NN'), ('shoulders', 'NNS'), ('first', 'RB')]
# ['second', 'laptop', 'head', 'shoulders', 'first']
#
#
# at first!
# [('first', 'RB')]
# ['first']
#
#
# Speaking of the browser, it too has problems.
# [('speaking', 'VBG'), ('browser', 'NN'), ('problems', 'NNS')]
# ['speaking', 'browser', 'problems']
#
#
# I think just going from PC to Mac has gotten me totally spoiled and I can't imagine ever going back.
# [('think', 'NN'), ('going', 'VBG'), ('pc', 'NN'), ('mac', 'NN'), ('gotten', 'VBN'), ('totally', 'RB'), ('spoiled', 'JJ'), ('ca', 'MD'), ("n't", 'RB'), ('imagine', 'VB'), ('ever', 'RB'), ('going', 'VBG'), ('back', 'RP')]
# ['think', 'going', 'pc', 'mac', 'gotten', 'totally', 'spoiled', 'ca', "n't", 'imagine', 'ever', 'going', 'back']
#
#
# The keyboard is too slick.
# [('keyboard', 'NN'), ('slick', 'NN')]
# ['keyboard', 'slick']
#
#
# Nightly my computer defrags itself and runs a virus scan.
# [('nightly', 'RB'), ('computer', 'NN'), ('defrags', 'NN'), ('runs', 'VBZ'), ('virus', 'JJ'), ('scan', 'JJ')]
# ['nightly', 'computer', 'defrags', 'runs', 'virus', 'scan']
#
#
# It's like 9 punds, but if you can look past it, it's GREAT!
# [("'s", 'POS'), ('like', 'IN'), ('9', 'CD'), ('punds', 'NNS'), ('look', 'VBP'), ('past', 'NN'), ("'s", 'POS'), ('great', 'JJ')]
# ["'s", 'like', '9', 'punds', 'look', 'past', "'s", 'great']
#
#
# It's just as fast with one program open as it is with sixteen open.
# [("'s", 'POS'), ('fast', 'JJ'), ('one', 'CD'), ('program', 'NN'), ('open', 'JJ'), ('sixteen', 'NN'), ('open', 'JJ')]
# ["'s", 'fast', 'one', 'program', 'open', 'sixteen', 'open']
#
#
# Still under warrenty so called Toshiba, no help at all.
# [('still', 'RB'), ('warrenty', 'NN'), ('called', 'VBN'), ('toshiba', 'NN'), ('help', 'NN')]
# ['still', 'warrenty', 'called', 'toshiba', 'help']
#
#
# I was happy with My purchase of a Toshiba Satellite L305D-S5934 laptop until it came time to have it repaired under the Toshiba Warranty.
# [('happy', 'JJ'), ('purchase', 'NN'), ('toshiba', 'NN'), ('satellite', 'JJ'), ('l305d-s5934', 'JJ'), ('laptop', 'NN'), ('came', 'VBD'), ('time', 'NN'), ('repaired', 'VBN'), ('toshiba', 'NNS'), ('warranty', 'NN')]
# ['happy', 'purchase', 'toshiba', 'satellite', 'l305d-s5934', 'laptop', 'came', 'time', 'repaired', 'toshiba', 'warranty']
#
#
# I LOVE IT!
# [('love', 'NN')]
# ['love']
#
#
# Amazing Quality!
# [('amazing', 'JJ'), ('quality', 'NN')]
# ['amazing', 'quality']
#
#
# The fact that you can spend over $100 on just a webcam underscores the value of this machine.
# [('fact', 'NN'), ('spend', 'VB'), ('100', 'CD'), ('webcam', 'NN'), ('underscores', 'NNS'), ('value', 'NN'), ('machine', 'NN')]
# ['fact', 'spend', '100', 'webcam', 'underscores', 'value', 'machine']
#
#
# I mainly use it for email, internet, and managing personal files (pics, vids, etc.).
# [('mainly', 'RB'), ('use', 'NN'), ('email', 'JJ'), ('internet', 'NN'), ('managing', 'VBG'), ('personal', 'JJ'), ('files', 'NNS'), ('pics', 'NNS'), ('vids', 'NNS'), ('etc', 'VBP')]
# ['mainly', 'use', 'email', 'internet', 'managing', 'personal', 'files', 'pics', 'vids', 'etc']
#
#
# A month or so ago, the freaking motherboard just died.
# [('month', 'NN'), ('ago', 'IN'), ('freaking', 'VBG'), ('motherboard', 'NN'), ('died', 'VBD')]
# ['month', 'ago', 'freaking', 'motherboard', 'died']
#
#
# The system it comes with does not work properly, so when trying to fix the problems with it it started not working at all.
# [('system', 'NN'), ('comes', 'VBZ'), ('work', 'VBP'), ('properly', 'RB'), ('trying', 'VBG'), ('fix', 'NN'), ('problems', 'NNS'), ('started', 'VBD'), ('working', 'VBG')]
# ['system', 'comes', 'work', 'properly', 'trying', 'fix', 'problems', 'started', 'working']
#
#
# Then after 4 or so months the charger stopped working so I was forced to go out and buy new hardware just to keep this computer running.
# [('4', 'CD'), ('months', 'NNS'), ('charger', 'NN'), ('stopped', 'VBD'), ('working', 'VBG'), ('forced', 'VBN'), ('go', 'VB'), ('buy', 'VB'), ('new', 'JJ'), ('hardware', 'NN'), ('keep', 'JJ'), ('computer', 'NN'), ('running', 'VBG')]
# ['4', 'months', 'charger', 'stopped', 'working', 'forced', 'go', 'buy', 'new', 'hardware', 'keep', 'computer', 'running']
#
#
# I took it back to Best Buy where they were so helpful and immediately gave me a new one.
# [('took', 'VBD'), ('back', 'RP'), ('best', 'JJS'), ('buy', 'NN'), ('helpful', 'JJ'), ('immediately', 'RB'), ('gave', 'VBD'), ('new', 'JJ'), ('one', 'CD')]
# ['took', 'back', 'best', 'buy', 'helpful', 'immediately', 'gave', 'new', 'one']
#
#
# If you had PC for four years I can almost gaurentee that something would of gone wrong by now, maybe even forcing you to replace your entire computer.
# [('pc', 'NN'), ('four', 'CD'), ('years', 'NNS'), ('almost', 'RB'), ('gaurentee', 'NN'), ('something', 'NN'), ('would', 'MD'), ('gone', 'VBN'), ('wrong', 'JJ'), ('maybe', 'RB'), ('even', 'RB'), ('forcing', 'VBG'), ('replace', 'VB'), ('entire', 'JJ'), ('computer', 'NN')]
# ['pc', 'four', 'years', 'almost', 'gaurentee', 'something', 'would', 'gone', 'wrong', 'maybe', 'even', 'forcing', 'replace', 'entire', 'computer']
#
#
# *2 weeks after giving the computer for repair*-Called headquarters, they report that they have not looked at it yet but it is "on the top of the stack".
# [('*2', 'JJ'), ('weeks', 'NNS'), ('giving', 'VBG'), ('computer', 'NN'), ('repair*-called', 'JJ'), ('headquarters', 'NNS'), ('report', 'NN'), ('looked', 'VBD'), ('yet', 'RB'), ('``', '``'), ('top', 'JJ'), ('stack', 'NN'), ("''", "''")]
# ['*2', 'weeks', 'giving', 'computer', 'repair*-called', 'headquarters', 'report', 'looked', 'yet', '``', 'top', 'stack', "''"]
#
#
# This machine delivers.
# [('machine', 'NN'), ('delivers', 'NNS')]
# ['machine', 'delivers']
#
#
# Then 2 of my nephews were going into music and both fell in love with the MacBook Pro.
# [('2', 'CD'), ('nephews', 'NNS'), ('going', 'VBG'), ('music', 'NN'), ('fell', 'VBD'), ('love', 'VB'), ('macbook', 'NN'), ('pro', 'FW')]
# ['2', 'nephews', 'going', 'music', 'fell', 'love', 'macbook', 'pro']
#
#
# I complain again...
# [('complain', 'NN'), ('...', ':')]
# ['complain', '...']
#
#
# This laptop is insane!!!
# [('laptop', 'JJ'), ('insane', 'NN')]
# ['laptop', 'insane']
#
#
# If a website ever freezes (which is rare), its really easy to force quit.
# [('website', 'JJ'), ('ever', 'RB'), ('freezes', 'VBZ'), ('rare', 'JJ'), ('really', 'RB'), ('easy', 'JJ'), ('force', 'NN'), ('quit', 'NN')]
# ['website', 'ever', 'freezes', 'rare', 'really', 'easy', 'force', 'quit']
#
#
# It does run a little warm but that is a negligible concern.
# [('run', 'VB'), ('little', 'JJ'), ('warm', 'JJ'), ('negligible', 'JJ'), ('concern', 'NN')]
# ['run', 'little', 'warm', 'negligible', 'concern']
#
#
# It rarely works and when it does it's incredibly slow.
# [('rarely', 'RB'), ('works', 'VBZ'), ("'s", 'POS'), ('incredibly', 'RB'), ('slow', 'VB')]
# ['rarely', 'works', "'s", 'incredibly', 'slow']
#
#
# I also enjoy the fact that my MacBook Pro laptop allows me to run Windows 7 on it by using the VMWare program.
# [('also', 'RB'), ('enjoy', 'VB'), ('fact', 'NN'), ('macbook', 'JJ'), ('pro', 'JJ'), ('laptop', 'FW'), ('allows', 'NNS'), ('run', 'VBP'), ('windows', 'VBZ'), ('7', 'CD'), ('using', 'VBG'), ('vmware', 'NN'), ('program', 'NN')]
# ['also', 'enjoy', 'fact', 'macbook', 'pro', 'laptop', 'allows', 'run', 'windows', '7', 'using', 'vmware', 'program']
#
#
# It's so much easier to navigate through the operating system, to find files, and it runs a lot faster!
# [("'s", 'POS'), ('much', 'JJ'), ('easier', 'JJR'), ('navigate', 'NN'), ('operating', 'NN'), ('system', 'NN'), ('find', 'VBP'), ('files', 'NNS'), ('runs', 'VBZ'), ('lot', 'NN'), ('faster', 'RBR')]
# ["'s", 'much', 'easier', 'navigate', 'operating', 'system', 'find', 'files', 'runs', 'lot', 'faster']
#
#
# Purchased a Toshiba Lap top it worked good until just after the warrenty went out.
# [('purchased', 'VBN'), ('toshiba', 'JJ'), ('lap', 'NN'), ('top', 'NN'), ('worked', 'VBD'), ('good', 'JJ'), ('warrenty', 'NN'), ('went', 'VBD')]
# ['purchased', 'toshiba', 'lap', 'top', 'worked', 'good', 'warrenty', 'went']
#
#
# I always swore by PCs and would never consider a MAC.
# [('always', 'RB'), ('swore', 'RB'), ('pcs', 'NNS'), ('would', 'MD'), ('never', 'RB'), ('consider', 'VB'), ('mac', 'NN')]
# ['always', 'swore', 'pcs', 'would', 'never', 'consider', 'mac']
#
#
# what an elegant, wonderful machine.
# [('elegant', 'JJ'), ('wonderful', 'JJ'), ('machine', 'NN')]
# ['elegant', 'wonderful', 'machine']
#
#
# This is now my 3rd MacBook Pro and I really honestly love it!
# [('3rd', 'CD'), ('macbook', 'JJ'), ('pro', 'FW'), ('really', 'RB'), ('honestly', 'RB'), ('love', 'VB')]
# ['3rd', 'macbook', 'pro', 'really', 'honestly', 'love']
#
#
# for 2 months.
# [('2', 'CD'), ('months', 'NNS')]
# ['2', 'months']
#
#
# I wanted to purchase the extended warranty and they refused, because they knew it was trouble.
# [('wanted', 'JJ'), ('purchase', 'NN'), ('extended', 'VBD'), ('warranty', 'NN'), ('refused', 'VBD'), ('knew', 'NNS'), ('trouble', 'NN')]
# ['wanted', 'purchase', 'extended', 'warranty', 'refused', 'knew', 'trouble']
#
#
# Do you ever think HP would do that? NEVER!
# [('ever', 'RB'), ('think', 'VBP'), ('hp', 'NNS'), ('would', 'MD'), ('never', 'RB')]
# ['ever', 'think', 'hp', 'would', 'never']
#
#
# We upgraded the memory to four gigabytes in order to take advantage of the performace increase in speed.
# [('upgraded', 'JJ'), ('memory', 'NN'), ('four', 'CD'), ('gigabytes', 'VBZ'), ('order', 'NN'), ('take', 'NN'), ('advantage', 'NN'), ('performace', 'NN'), ('increase', 'NN'), ('speed', 'NN')]
# ['upgraded', 'memory', 'four', 'gigabytes', 'order', 'take', 'advantage', 'performace', 'increase', 'speed']
#
#
# It's not like I have used for half a year and then complained about it.
# [("'s", 'POS'), ('like', 'IN'), ('used', 'VBN'), ('half', 'NN'), ('year', 'NN'), ('complained', 'VBD')]
# ["'s", 'like', 'used', 'half', 'year', 'complained']
#
#
# Still trying to learn how to use it.
# [('still', 'RB'), ('trying', 'VBG'), ('learn', 'NN'), ('use', 'NN')]
# ['still', 'trying', 'learn', 'use']
#
#
# The reality was, it heated up very quickly, and took way too long to do simple things, like opening my Documents folder.
# [('reality', 'NN'), ('heated', 'VBD'), ('quickly', 'RB'), ('took', 'VBD'), ('way', 'NN'), ('long', 'RB'), ('simple', 'JJ'), ('things', 'NNS'), ('like', 'IN'), ('opening', 'VBG'), ('documents', 'NNS'), ('folder', 'NN')]
# ['reality', 'heated', 'quickly', 'took', 'way', 'long', 'simple', 'things', 'like', 'opening', 'documents', 'folder']
#
#
# I bought the netbook because it was smaller and lighter for me to carry around.
# [('bought', 'VBN'), ('netbook', 'RB'), ('smaller', 'JJR'), ('lighter', 'NN'), ('carry', 'VBP'), ('around', 'IN')]
# ['bought', 'netbook', 'smaller', 'lighter', 'carry', 'around']
#
#
# The Genius at the Apple store advised me that there was nothing about my use of the computer that caused this failure.
# [('genius', 'NN'), ('apple', 'NN'), ('store', 'NN'), ('advised', 'VBD'), ('nothing', 'NN'), ('use', 'NN'), ('computer', 'NN'), ('caused', 'VBD'), ('failure', 'NN')]
# ['genius', 'apple', 'store', 'advised', 'nothing', 'use', 'computer', 'caused', 'failure']
#
#
# We'll save our money to replace it with a Mac again!
# [("'ll", 'MD'), ('save', 'VB'), ('money', 'NN'), ('replace', 'VB'), ('mac', 'NN')]
# ["'ll", 'save', 'money', 'replace', 'mac']
#
#
# Thank you for your great product!
# [('thank', 'NN'), ('great', 'JJ'), ('product', 'NN')]
# ['thank', 'great', 'product']
#
#
# this company truely does make horrible products and doesnt seem to because they are certain things like this "never" happen...
# [('company', 'NN'), ('truely', 'RB'), ('make', 'VBP'), ('horrible', 'JJ'), ('products', 'NNS'), ('doesnt', 'VBN'), ('seem', 'VBP'), ('certain', 'JJ'), ('things', 'NNS'), ('like', 'IN'), ('``', '``'), ('never', 'RB'), ("''", "''"), ('happen', 'NN'), ('...', ':')]
# ['company', 'truely', 'make', 'horrible', 'products', 'doesnt', 'seem', 'certain', 'things', 'like', '``', 'never', "''", 'happen', '...']
#
#
# I had always used PCs and been constantly frustrated by the crashing and the poorly designed operating systems that were never very intuitive.
# [('always', 'RB'), ('used', 'VBN'), ('pcs', 'NNS'), ('constantly', 'RB'), ('frustrated', 'VBD'), ('crashing', 'VBG'), ('poorly', 'RB'), ('designed', 'VBN'), ('operating', 'VBG'), ('systems', 'NNS'), ('never', 'RB'), ('intuitive', 'VBP')]
# ['always', 'used', 'pcs', 'constantly', 'frustrated', 'crashing', 'poorly', 'designed', 'operating', 'systems', 'never', 'intuitive']
#
#
# Sorry Toshiba, but 1st impressions do count for something.
# [('sorry', 'NN'), ('toshiba', 'VBD'), ('1st', 'CD'), ('impressions', 'NNS'), ('count', 'VBP'), ('something', 'NN')]
# ['sorry', 'toshiba', '1st', 'impressions', 'count', 'something']
#
#
# Then, within 5 months, the charger crapped out on me.
# [('within', 'IN'), ('5', 'CD'), ('months', 'NNS'), ('charger', 'NN'), ('crapped', 'VBD')]
# ['within', '5', 'months', 'charger', 'crapped']
#
#
# And if you have a iphone or ipod touch you can connect and download songs to it at high speed.
# [('iphone', 'NN'), ('ipod', 'NN'), ('touch', 'JJ'), ('connect', 'NN'), ('download', 'NN'), ('songs', 'NNS'), ('high', 'JJ'), ('speed', 'NN')]
# ['iphone', 'ipod', 'touch', 'connect', 'download', 'songs', 'high', 'speed']
#
#
# Overall this laptop is great.
# [('overall', 'JJ'), ('laptop', 'JJ'), ('great', 'JJ')]
# ['overall', 'laptop', 'great']
#
#
# I love the glass touchpad.
# [('love', 'NN'), ('glass', 'NN'), ('touchpad', 'NN')]
# ['love', 'glass', 'touchpad']
#
#
# I continued to take the computer in AGAIN and they replaced the hard drive and mother board yet again.
# [('continued', 'JJ'), ('take', 'VB'), ('computer', 'NN'), ('replaced', 'VBN'), ('hard', 'JJ'), ('drive', 'NN'), ('mother', 'NN'), ('board', 'NN'), ('yet', 'RB')]
# ['continued', 'take', 'computer', 'replaced', 'hard', 'drive', 'mother', 'board', 'yet']
#
#
# I am using the external speaker- sound is good.
# [('using', 'VBG'), ('external', 'JJ'), ('speaker-', 'JJ'), ('sound', 'NN'), ('good', 'JJ')]
# ['using', 'external', 'speaker-', 'sound', 'good']
#
#
# The Apple MC371LL/A 2.4Ghz 15.4-inch MacBook Pro Notebook is a horrible waste of money.
# [('apple', 'NN'), ('mc371ll/a', 'NN'), ('2.4ghz', 'CD'), ('15.4-inch', 'JJ'), ('macbook', 'NN'), ('pro', 'JJ'), ('notebook', 'NN'), ('horrible', 'JJ'), ('waste', 'NN'), ('money', 'NN')]
# ['apple', 'mc371ll/a', '2.4ghz', '15.4-inch', 'macbook', 'pro', 'notebook', 'horrible', 'waste', 'money']
#
#
# Ok, this is probably the best laptop series ever devised by Apple.
# [('ok', 'NN'), ('probably', 'RB'), ('best', 'JJS'), ('laptop', 'JJ'), ('series', 'NN'), ('ever', 'RB'), ('devised', 'VBD'), ('apple', 'NN')]
# ['ok', 'probably', 'best', 'laptop', 'series', 'ever', 'devised', 'apple']
#
#
# As of a couple weeks ago the middle portion of the laptop from top to bottom,,,about 4 inches across is hardly visible.
# [('couple', 'NN'), ('weeks', 'NNS'), ('ago', 'RB'), ('middle', 'JJ'), ('portion', 'NN'), ('laptop', 'JJ'), ('top', 'NN'), ('bottom', 'NN'), ('4', 'CD'), ('inches', 'NNS'), ('across', 'IN'), ('hardly', 'RB'), ('visible', 'JJ')]
# ['couple', 'weeks', 'ago', 'middle', 'portion', 'laptop', 'top', 'bottom', '4', 'inches', 'across', 'hardly', 'visible']
#
#
# still testing the battery life as i thought it would be better, but am very happy with the upgrade.
# [('still', 'RB'), ('testing', 'VBG'), ('battery', 'NN'), ('life', 'NN'), ('thought', 'VBD'), ('would', 'MD'), ('better', 'VB'), ('happy', 'JJ'), ('upgrade', 'NN')]
# ['still', 'testing', 'battery', 'life', 'thought', 'would', 'better', 'happy', 'upgrade']
#
#
# Then HP sends it back to me with the hardware screwed up, not able to connect.
# [('hp', 'NN'), ('sends', 'VBZ'), ('back', 'RB'), ('hardware', 'NN'), ('screwed', 'VBD'), ('able', 'JJ'), ('connect', 'NN')]
# ['hp', 'sends', 'back', 'hardware', 'screwed', 'able', 'connect']
#
#
# I just hope the reputation that Toshiba has is true and I won't have to worry about a crash.
# [('hope', 'NN'), ('reputation', 'NN'), ('toshiba', 'VBZ'), ('true', 'JJ'), ('wo', 'MD'), ("n't", 'RB'), ('worry', 'VB'), ('crash', 'NN')]
# ['hope', 'reputation', 'toshiba', 'true', 'wo', "n't", 'worry', 'crash']
#
#
# Oh yeah, don't forget the expensive shipping to and from HP.
# [('oh', 'UH'), ('yeah', 'VBP'), ("n't", 'RB'), ('forget', 'VB'), ('expensive', 'JJ'), ('shipping', 'NN'), ('hp', 'NN')]
# ['oh', 'yeah', "n't", 'forget', 'expensive', 'shipping', 'hp']
#
#
# I would recommend anyone to buy from pcconnection express.
# [('would', 'MD'), ('recommend', 'VB'), ('anyone', 'NN'), ('buy', 'NN'), ('pcconnection', 'NN'), ('express', 'NN')]
# ['would', 'recommend', 'anyone', 'buy', 'pcconnection', 'express']
#
#
# Good luck.
# [('good', 'JJ'), ('luck', 'NN')]
# ['good', 'luck']
#
#
# Everything is so easy to use, Mac software is just so much simpler than Microsoft software.
# [('everything', 'NN'), ('easy', 'JJ'), ('use', 'NN'), ('mac', 'NN'), ('software', 'NN'), ('much', 'JJ'), ('simpler', 'NN'), ('microsoft', 'NN'), ('software', 'NN')]
# ['everything', 'easy', 'use', 'mac', 'software', 'much', 'simpler', 'microsoft', 'software']
#
#
# My favorite by far, although the most expensive, was my Sony.
# [('favorite', 'RB'), ('far', 'RB'), ('although', 'IN'), ('expensive', 'JJ'), ('sony', 'NN')]
# ['favorite', 'far', 'although', 'expensive', 'sony']
#
#
# And if you do a lot of writing, editing is a problem since there is no  forward delete  key.
# [('lot', 'NN'), ('writing', 'VBG'), ('editing', 'VBG'), ('problem', 'NN'), ('since', 'IN'), ('forward', 'RB'), ('delete', 'JJ'), ('key', 'NN')]
# ['lot', 'writing', 'editing', 'problem', 'since', 'forward', 'delete', 'key']
#
#
# Also I typed faster then then letters would show and it got to be realy annoying.
# [('also', 'RB'), ('typed', 'VBD'), ('faster', 'JJR'), ('letters', 'NNS'), ('would', 'MD'), ('show', 'VB'), ('got', 'VBD'), ('realy', 'JJ'), ('annoying', 'NN')]
# ['also', 'typed', 'faster', 'letters', 'would', 'show', 'got', 'realy', 'annoying']
#
#
# As an owner of a Toshiba Satalite laptop computer things you should know before you buy.
# [('owner', 'NN'), ('toshiba', 'VBZ'), ('satalite', 'JJ'), ('laptop', 'JJ'), ('computer', 'NN'), ('things', 'NNS'), ('know', 'VBP'), ('buy', 'VB')]
# ['owner', 'toshiba', 'satalite', 'laptop', 'computer', 'things', 'know', 'buy']
#
#
# Its ease of use and the top service from Apple- be it their phone assistance or bellying up to the genius bar- cannot be beat.
# [('ease', 'NN'), ('use', 'NN'), ('top', 'JJ'), ('service', 'NN'), ('apple-', 'JJ'), ('phone', 'NN'), ('assistance', 'NN'), ('bellying', 'VBG'), ('genius', 'JJ'), ('bar-', 'JJ'), ('beat', 'NN')]
# ['ease', 'use', 'top', 'service', 'apple-', 'phone', 'assistance', 'bellying', 'genius', 'bar-', 'beat']
#
#
# It has a 10 hour battery life when you're doing web browsing and word editing, making it perfect for the classroom or office, and in terms of gaming and movie playing it'll have a battery life of just over 5 hours.
# [('10', 'CD'), ('hour', 'NN'), ('battery', 'NN'), ('life', 'NN'), ("'re", 'VBP'), ('web', 'JJ'), ('browsing', 'NN'), ('word', 'NN'), ('editing', 'VBG'), ('making', 'VBG'), ('perfect', 'JJ'), ('classroom', 'NN'), ('office', 'NN'), ('terms', 'NNS'), ('gaming', 'VBG'), ('movie', 'NN'), ('playing', 'NN'), ("'ll", 'MD'), ('battery', 'VB'), ('life', 'NN'), ('5', 'CD'), ('hours', 'NNS')]
# ['10', 'hour', 'battery', 'life', "'re", 'web', 'browsing', 'word', 'editing', 'making', 'perfect', 'classroom', 'office', 'terms', 'gaming', 'movie', 'playing', "'ll", 'battery', 'life', '5', 'hours']
#
#
# I shipped out on Saturday, July 17.
# [('shipped', 'VBN'), ('saturday', 'JJ'), ('july', 'RB'), ('17', 'CD')]
# ['shipped', 'saturday', 'july', '17']
#
#
# I bought it for really cheap also and it's AMAZING.
# [('bought', 'VBN'), ('really', 'RB'), ('cheap', 'JJ'), ('also', 'RB'), ("'s", 'POS'), ('amazing', 'VBG')]
# ['bought', 'really', 'cheap', 'also', "'s", 'amazing']
#
#
# Acer has set me up with FREE recovery discs, when they are available since I asked.
# [('acer', 'NN'), ('set', 'VBN'), ('free', 'JJ'), ('recovery', 'NN'), ('discs', 'NN'), ('available', 'JJ'), ('since', 'IN'), ('asked', 'VBN')]
# ['acer', 'set', 'free', 'recovery', 'discs', 'available', 'since', 'asked']
#
#
# I also purchased Office Max's "Max Assurance" with the "no lemon" clause.
# [('also', 'RB'), ('purchased', 'VBN'), ('office', 'NN'), ('max', 'NN'), ("'s", 'POS'), ('``', '``'), ('max', 'FW'), ('assurance', 'NN'), ("''", "''"), ('``', '``'), ('lemon', 'NN'), ("''", "''"), ('clause', 'NN')]
# ['also', 'purchased', 'office', 'max', "'s", '``', 'max', 'assurance', "''", '``', 'lemon', "''", 'clause']
#
#
# If you find yourself in the market for a new laptop (and have the money) don't exclude looking at the MBPs.
# [('find', 'VB'), ('market', 'NN'), ('new', 'JJ'), ('laptop', 'JJ'), ('money', 'NN'), ("n't", 'RB'), ('exclude', 'VBD'), ('looking', 'VBG'), ('mbps', 'NN')]
# ['find', 'market', 'new', 'laptop', 'money', "n't", 'exclude', 'looking', 'mbps']
#
#
# I eventually did the migration from my iMac backup disc which uses USB.
# [('eventually', 'RB'), ('migration', 'NN'), ('imac', 'NN'), ('backup', 'NN'), ('disc', 'NN'), ('uses', 'VBZ'), ('usb', 'JJ')]
# ['eventually', 'migration', 'imac', 'backup', 'disc', 'uses', 'usb']
#
#
# Those things are very important - vital even!
# [('things', 'NNS'), ('important', 'JJ'), ('vital', 'JJ'), ('even', 'RB')]
# ['things', 'important', 'vital', 'even']
#
#
# -They say it will take "up to two weeks".
# [('-they', 'NNS'), ('say', 'VBP'), ('take', 'VB'), ('``', '``'), ('two', 'CD'), ('weeks', 'NNS'), ("''", "''")]
# ['-they', 'say', 'take', '``', 'two', 'weeks', "''"]
#
#
# I didn't like one thing about it.
# [("n't", 'RB'), ('like', 'IN'), ('one', 'CD'), ('thing', 'NN')]
# ["n't", 'like', 'one', 'thing']
#
#
# The battery life seems to be very good, and have had no issues with it.
# [('battery', 'NN'), ('life', 'NN'), ('seems', 'VBZ'), ('good', 'JJ'), ('issues', 'NNS')]
# ['battery', 'life', 'seems', 'good', 'issues']
#
#
# Enabling the battery timer is useless.
# [('enabling', 'VBG'), ('battery', 'NN'), ('timer', 'NN'), ('useless', 'NN')]
# ['enabling', 'battery', 'timer', 'useless']
#
#
# Temperatures on the outside were alright but i did not track in Core Processing Unit temperatures.
# [('temperatures', 'NNS'), ('outside', 'JJ'), ('alright', 'JJ'), ('track', 'NN'), ('core', 'NN'), ('processing', 'NN'), ('unit', 'NN'), ('temperatures', 'NNS')]
# ['temperatures', 'outside', 'alright', 'track', 'core', 'processing', 'unit', 'temperatures']
#
#
# Yeah, to you.
# [('yeah', 'NN')]
# ['yeah']
#
#
# I got a mac as my HS graduation gift.
# [('got', 'VBD'), ('mac', 'JJ'), ('hs', 'JJ'), ('graduation', 'NN'), ('gift', 'NN')]
# ['got', 'mac', 'hs', 'graduation', 'gift']
#
#
# I have now had it for 1.5 months and love it.
# [('1.5', 'CD'), ('months', 'NNS'), ('love', 'VB')]
# ['1.5', 'months', 'love']
#
#
# It turned out it's not really a problem to have a Mac.
# [('turned', 'VBN'), ("'s", 'POS'), ('really', 'RB'), ('problem', 'NN'), ('mac', 'NN')]
# ['turned', "'s", 'really', 'problem', 'mac']
#
#
# Page just disapeared after you got yahoo or downloaded something.
# [('page', 'NN'), ('disapeared', 'VBD'), ('got', 'VBD'), ('yahoo', 'RB'), ('downloaded', 'VBN'), ('something', 'NN')]
# ['page', 'disapeared', 'got', 'yahoo', 'downloaded', 'something']
#
#
# Images can be multi-selected and viewed swiftly or in slideshow mode.
# [('images', 'NNS'), ('multi-selected', 'JJ'), ('viewed', 'VBN'), ('swiftly', 'RB'), ('slideshow', 'VBP'), ('mode', 'NN')]
# ['images', 'multi-selected', 'viewed', 'swiftly', 'slideshow', 'mode']
#
#
# Going to bring it to service today.
# [('going', 'VBG'), ('bring', 'NN'), ('service', 'NN'), ('today', 'NN')]
# ['going', 'bring', 'service', 'today']
#
#
# There is no need to purchase virus protection for Mac, which saves me a lot of time and money.
# [('need', 'JJ'), ('purchase', 'NN'), ('virus', 'NN'), ('protection', 'NN'), ('mac', 'NN'), ('saves', 'VBZ'), ('lot', 'JJ'), ('time', 'NN'), ('money', 'NN')]
# ['need', 'purchase', 'virus', 'protection', 'mac', 'saves', 'lot', 'time', 'money']
#
#
# But we had paid for bluetooth, and there was none.
# [('paid', 'VBN'), ('bluetooth', 'DT'), ('none', 'NN')]
# ['paid', 'bluetooth', 'none']
#
#
# So, I paid a visit to LG notebook service center at Alexandra Road, hoping they can make the hinge tighter.
# [('paid', 'VBN'), ('visit', 'NN'), ('lg', 'NN'), ('notebook', 'NN'), ('service', 'NN'), ('center', 'NN'), ('alexandra', 'VBP'), ('road', 'NN'), ('hoping', 'VBG'), ('make', 'VBP'), ('hinge', 'NN'), ('tighter', 'NN')]
# ['paid', 'visit', 'lg', 'notebook', 'service', 'center', 'alexandra', 'road', 'hoping', 'make', 'hinge', 'tighter']
#
#
# My daughter uses it for games, email, facebook, pictures and music.
# [('daughter', 'NN'), ('uses', 'VBZ'), ('games', 'NNS'), ('email', 'VBP'), ('facebook', 'NN'), ('pictures', 'NNS'), ('music', 'NN')]
# ['daughter', 'uses', 'games', 'email', 'facebook', 'pictures', 'music']
#
#
# Laptop is to be used like a Netbook.
# [('laptop', 'NN'), ('used', 'VBN'), ('like', 'IN'), ('netbook', 'NN')]
# ['laptop', 'used', 'like', 'netbook']
#
#
# It is always reliable, never bugged and responds well.
# [('always', 'RB'), ('reliable', 'JJ'), ('never', 'RB'), ('bugged', 'VBN'), ('responds', 'NNS'), ('well', 'RB')]
# ['always', 'reliable', 'never', 'bugged', 'responds', 'well']
#
#
# After about a week I finally got it back and was told that the motherboard had failed and so they installed a new motherboard.
# [('week', 'NN'), ('finally', 'RB'), ('got', 'VBD'), ('back', 'RB'), ('told', 'VBN'), ('motherboard', 'NN'), ('failed', 'VBD'), ('installed', 'JJ'), ('new', 'JJ'), ('motherboard', 'NN')]
# ['week', 'finally', 'got', 'back', 'told', 'motherboard', 'failed', 'installed', 'new', 'motherboard']
#
#
# Trying to balance all of my roles leaves very little time for me to do anything, so I want to manage my time I do have to be the most efficient.
# [('trying', 'VBG'), ('balance', 'NN'), ('roles', 'NNS'), ('leaves', 'VBZ'), ('little', 'JJ'), ('time', 'NN'), ('anything', 'NN'), ('want', 'JJ'), ('manage', 'NN'), ('time', 'NN'), ('efficient', 'NN')]
# ['trying', 'balance', 'roles', 'leaves', 'little', 'time', 'anything', 'want', 'manage', 'time', 'efficient']
#
#
# ...
# At home and the office it gets plugged into an external 24" LCD screen, so built in screen size is not terribly important.
# Hopefully my replacement is brand new.
# Just beware no DVD slot so when I went to install software I had on CD I couldn't.
# I bought it to be able to dedicate a small, portable laptop to my writing and was surprised to learn that I needed to buy a word processing program to do so.
# This version of MacBook Pro runs on a third-generation CPU ("Ivy Bridge"), not the latest fourth-generation Haswell CPU the 2013 version has.
# Actually, I think I was intimidated by the change from a PC.
# No Cd Rom in the new version there's no way I'm spending that kind of money on something has less features than the older version.
# Definitely worth spending the money on it.
# I have three words: Piece of Junk!
# the volume is really low to low for a laptopwas not expectin t volume to be so lowan i hate that about this computer
# Fits all my personal needs.
# I'm the pro-active type so I went off and did some preventative fixes.
# and its not hard to accidentally bang it against something so i recommend getting a case to protect it.
# I wanted to explore what the Mac was all about.
# I got this at an amazing price from Amazon and it arrived just in time.
# Every time I log into the system after a few hours, there is this endlessly frustrating process that I have to go through.
# The majority of the reviews seem to be for the 13.3 MacBook Pro  Model # MD101LL/A.
# Put a SSD and use a 21" LED screen, this set up is silky smooth!
# I saw the bad reviews from people saying to buy directly from Apple and I was concerned but I took my chances and am overly impressed.
# The case is now slightly larger than the previous generation, but the lack of an external power supply justifies the small increase in size.
# I had to buy a wireless mouse to go with it, as I am old school and hate the pad, but knew that before I bought it, now it works great, need to get adjusted to the key board, as I am used to a bigger one and pounding.
# When considering a Mac, look at the total cost of ownership and not just the initial price tag.
# Has all the other features I wanted including a VGA port, HDMI, ethernet and 3 USB ports.
# A great college tool!
# The only thing I dislike about this laptop are the rubber pads found on the bottom of the computer for grip.
# I called apple and no solution.
# It's a decent computer for the price and hopefully it will last a long time.
# I was really happy because it is a much better price on amazon.com than it was in the Mac store.
# The worst a Mac ever did to me was freeze up.
# The nicest  part is the low heat output and ultra quiet operation.
# I am paying apple to kill my self and my wallet.
# NO STAR FOR THIS TRASH.[...
# I will upgrade the ram myself (because with this model you can you can do it) later on.
# The price is 200 dollars down.
# this Mac Mini does not have a built-in mic, and it would seem that its Mac OS 10.9 does not handle external microphones properly.
# A lot of features and shortcuts on the MBP that I was never exposed to on a normal PC.
# Wasn't sure if I was going to like it much less love it so I went to a local best buy and played around with the IOS system on a Mac Pro and it was totally unique and different.
# Quietest laptop I have ever owned.
# air has higher resolution but the fonts are small.
# again this is just my personal honest opinion.
# If you have much higher expectations than that... I would look elsewhere.
# working with Mac is so much easier, so many cool features.
# I'm going to buy a logitevh c270.
# Very happy with my purchase.
# I like the brightness and adjustments.
# I'M SO HAPPY WITH MY macbook pro!
# I only wish this mac had a CD/DVD player built in.
# The only thing I miss is that my old Alienware laptop had backlit keys.
# The only thing I miss are the "Home/End" type keys and other things that I grew accustomed to after so long.
# So happy with this purchase, I just wish it came with Microsoft Word.
# It is more than enough computer to keep up with the needs of a high school student.
# It has enough memory and speed to run my business with all the flexibility that comes with a laptop.
# The speed, the simplicity, the design.. it is lightyears ahead of any PC I have ever owned.
# I love everything about this computer.
# I found it toughest to decide between Dell ultra books and Apple.
# The battery life is excellent, the display is excellent, and downloading apps is a  breeze.
# The screen, the software and the smoothness of the operating system.
# While we struggle with all the crashes and viruses, the kids computers stay consistent and so we caved in and bought one for buisness!
# I don't want to RUN a computer; I want to USE a computer.
# i have dropped mine a couple times with only a slim plastic case covering it.
# I also made a recovery USB stick.
# Being a PC user for many years to switch to a Mac I will not go back.
# But with this laptop, the bass is very weak and the sound comes out sounding tinny.
# I do admit it is pricey but the saying is really true with this MacBook Pro Laptop ( You get what you pay for).
# I've almost have bought every generation of MacMinis since 2005, and this one hasn't let me down.
# The built quality is really good, I was so Happy and excited about this Product.
# I am loving the fast performance also.
# I had to return it because it wouldn't even start.
# Further, this Mac Mini has a sloppy Bluetooth interface (courtesy of the Mac OS) and the range is poor.
# Great deal on an amazing lap top!
# If you start on the far right side and scroll to your left the start menu will automatically come up.
# Best money I ever spent.
# My only gripe would be the need to add more RAM.
# But I didn't want to spend another thousand on a laptop since my work already provides me with a PC.
# Fine if you have a touch screen.
# can never go wrong with apple products.
# As far as user type - I dabble in everything from games (WoW) to Photoshop, but nothing professionally.
# It doesnt get hot like my PC, with technology always at the tip of our fingertips anytime I forget how to do something i just google it.
# I re-seated the "WLAN" card inside and re-installed the LAN device drivers.
# This by far beats any computer out on the market today built well, battery life AMAZING.
# I haven't used it for anything high tech yet, but I love it already.
# The OS is easy, and offers all kinds of surprises.
# I had to get Apple Customer Support to correct the problem.
# Ideal for someone on the go or for a high school students.
# A veryimportant feature is Firewire 800 which in my experience works better then USB3 (in PC enabled with USB3)I was not originally sold on the MAC OS I felt it was inferior in many ways To Windows 7.
# I like iTunes, the apparent security, the Mini form factor, all the nice graphics stuff.
# The first time I used the card reader it took half an hour and a pair of tweezers to remove the card.
# This flaw unfortunately detracts from everything else Apple got right with the Mini.
# After replacing the spinning hard disk with an ssd drive, my mac is just flying.
# I know some people complained about HDMI issues but they released a firmware patch to address that issue.
# With the needs of a professional photographer I generally need to keep up with the best specs.
# Added an iMac about 2 years later.
# packing and everything was perfect
# I will not hesitate to recommend it to family and friends
# I called Toshiba where I gave them the serial number and they informed me that they were having issues with the mother boards.
# I seem to be having repeat problems as the Mother Board in this one is diagnosed as faulty, related to the graphics card.
# It also comes with 4G of RAM but if you're like me you want to max that out so I immediately put 8G of RAM in her and I've never used a computer that performs better.
# This computer is also awesome for my sons virtual home schooling.
# Cost is more as compared to other brands.
# also...- excellent operating system- size and weight for optimal mobility- excellent durability of the battery- the functions provided by the trackpad is unmatched by any other brand-
# This hardware seems to be better than the iMac in that it isn't $1400 and smaller.
# I'm done with WinDoze computers.
# I've had it for about 2 months now and found no issues with software or updates.
# the latest version does not have a disc drive.
# Screen - although some people might complain about low res which I think is ridiculous.
# --------------------------------------------------------------------------------------------------------
# Boot time
# tech support
# Set up
# Windows 8
# touchscreen functions
# internal speakers
# price tag
# click pads
# installation disk (DVD)
# use
# Works
# apple OS
# features
# log on
# WiFi connection
# battery life
# delete key
# interneting
# priced
# works
# track pad
# graphics
# mountain lion
# durability
# build
# battery life
# works
# Windows 8
# baterry
# size
# weight
# performance
# USB ports
# speed
# screen
# price
# Hardware performance
# works
# set up
# Keyboard
# Windows 8
# setup
# configure
# Windows 8
# usb ports
# features
# screen
# keyboard
# Performance
# quality
# performance
# OS
# portability
# portable computing
# Windows 8
# MS Office 2011 for Mac
# performance
# look
# performance
# lit up keys
# screen display
# Mountain Lion OS
# Microsoft Windows
# OSX
# Microsoft Office
# graphics
# colors
# Built-in apps
# Screen resolution
# operating system
# Windows
# speed
# multi touch gestures
# size
# SquareTrade 3-Year Computer Accidental Protection Warranty
# AppleCare
# transport
# Windows 8 Set-Up
# size
# retina display
# design
# aluminum casing
# aluminum body
# integrate bluetooth devices
# USB devices
# Intel4000 graphic chip
# DVD drive Firewire port
# adapter
# SDXC slot
# durability
# designed
# use
# value
# specs
# product quality
# aesthetics
# craftmanship
# customer service
# size
# windows 8
# Windows 8
# Startup times
# colors
# price
# shipping
# mouse
# battery
# windows 7
# price
# delivery
# service
# customer service
# windows 8
# price
# Set up
# Win8
# features
# price
# OSX
# support for games
# mobility
# price
# set up
# USB3
# sound
# track pad
# settings
# OpenOffice
# form factor
# battery life
# UX
# keyboard
# screen
# touchpad
# Mavericks
# i5
# service
# shipping
# performance
# built-in applications
# iPhoto
# hard drive
# Samsung 830 SSD
# Starts up
# aluminum
# built in virus control
# retina display
# components
# hardware
# battery
# snow lion
# shipping
# features
# quality
# keyboard
# sound quality
# navigate
# battery life
# Performance
# Quality
# windows XP
# windows Vista
# Windows 7
# SSD drive
# memory
# start up
# itune
# OS
# restore disks
# charging cables
# material
# graphic design
# external mics
# os
# screen
# works
# System
# customize setting
# create your own bookmarks
# wireless keyboard / mouse
# HDMI cable
# features
# price
# working
# gaming
# operating system
# set up
# hard drive
# boots up
# scanning
# price point
# works
# working
# surfing
# works
# software
# word processing
# web browsing
# gaming
# programming
# function
# performance
# Apple "Help"
# work
# Harddrive
# on/off switch
# instructions
# gaming
# integrated Intel 4000 graphics
# features
# content creation
# Audio
# video
# photo editing
# Screen
# brightness
# applications
# use
# use
# i5 processor
# built in features
# screen
# keyboard
# delivery
# SSD
# 16Gb RAM
# memory
# works
# design
# keyboard
# ports
# service
# Web browsing
# Safari browser
# lighted screen
# use
# start up
# operation
# USB3 Peripherals
# ThunderBolt
# warranty
# media editing
# battery
# user experience
# shipment
# price
# performance
# usability
# presentation
# time response
# size
# Mac OS
# Legacy programs
# Appleworks
# FileMaker Pro
# Quicken
# Photoshop
# operating system
# form factor
# loading the internet
# looking
# XP
# support
# OS
# overall build
# keyboard
# construction
# system
# unibody construction
# runs
# disk drive
# HDMI receptacle
# SD card slot
# works
# design app
# TRACKPAD
# finish
# looks
# feels
# Price
# price
# system
# power down
# configuration
# speakers
# looks
# use
# trackpad
# Web surfuring
# interface
# portability
# works
# carry
# handle
# performance
# battery lifetime
# hardware (keyboard)
# Runs
# footprint
# exterior
# performance
# intel 4000 graphics chipset
# design
# OSX Mountain Lion
# Mavericks
# USB ports
# lid
# wakes
# size
# speed
# CUSTOMER SERVICE
# performed
# battery cycle count
# hardware
# OS
# finger swipes
# mouse
# storage
# screen
# photoshop
# Mac OS
# speaker quality
# Shipped
# thunderbolt port
# performance
# streaming video
# entertainment uses
# design
# features
# Mac office
# Apple Tech Support
# spec
# works
# use
# looks
# Office
# retina display
# Performance
# SSD
# MagSafe accessories
# MagSafe 2 connection
# touchpad
# mouse
# runs
# fans
# Mac OS
# Mac ecosystem
# price
# use
# appearance
# functionality
# graphic design
# slot
# OS
# use
# SSD
# built-in camera
# voice recording
# start up
# functionality
# function
# Graphics
# Build Quality
# unibody construction
# flexibility for connectivity
# portability
# Mac tutorials
# technical support
# adapter
# technical support
# iPhoto
# garage band
# Logic board
# sound
# volume
# OSX Lion
# application
# physical form
# body
# unibody construction
# 3D rendering
# OS X Mountain Lion
# screen
# apps
# priced
# cost
# boot
# ports
# Quad-Core 2.5 GHz CPU
# Radeon HD 6750M 512MB graphic card
# integrated Intel 4000 card
# wireless Apple Keyboard and Mouse
# package
# cover
# gestures
# extender cable
# cable
# 2.9ghz dual-core i7 chip
# starts up
# heat
# noise
# Windows 8
# internal CD drive
# hard drive
# network lights
# priced
# storage
# ports
# audio volume
# size
# Windows 8
# capabilities
# settings
# Runs
# Boot-up
# Windows updates
# logic board
# internet
# word processing
# graphic design
# gaming
# setup
# install
# tutorial
# features
# right mouse click menu
# Runs
# RAM memory
# profile
# disk drive
# USB ports
# WiFi capability
# SD card reader
# nail slot on the card
# slot
# touch
# anodized aluminum
# aluminium
# glass
# aluminum
# 16GB of RAM
# Seagate Momentus XT hybrid drives
# OWC upgrade kit
# hard drive
# number pad on the keyboard
# regular hard drive
# CD slot
# HDMI port
# install Mountain Lion
# Customization
# HD
# Micron SSD
# two finger clicking
# right click button
# SuperDrive
# power plug
# power adaptor
# battery
# battery
# practicality
# OS
# monitors
# HDMI cables
# Price
# AC adaptor
# Fan
# playing a game
# USB 2 ports
# startup disk
# "tools" menu
# word program
# CD/DVD drive
# power switch
# Windows 7
# Windows 8
# install
# configure for ADSl cable or wifi
# speakers
# packing
# windows
# iDVD
# Windows 7
# Mac system
# windows
# works
# software
# OS
# works
# Runs
# price
# OS
# touch pad
# reliability
# sound
# headphones
# track pad
# OS
# application
# price
# battery
# price
# speed
# Shipping
# retina display display
# compact computing
# performance and feature set of the hardware
# ports
# FireWire 800
# Gigabit Ethernet
# MagSafe port
# Microphone jack
# ventilation system
# watching videos
# playing steam games
# Acer support
# operating system files
# keys
# OS
# Lion
# MAC OS
# RAM
# HDD
# CD/DVD player
# RAM memory
# os.x
# windows
# windows
# OS
# softwares
# Mac OS X 10.8 "Mountain Lion"
# performance
# built in screen size
# external 24" LCD screen
# install software
# DVD slot
# word processing program
# third-generation CPU ("Ivy Bridge")
# fourth-generation Haswell CPU
# Cd Rom
# features
# volume
# volume
# case
# price
# log into the system
# 21" LED screen
# SSD
# set up
# case
# size
# external power supply
# wireless mouse
# pad
# works
# key board
# cost of ownership
# price tag
# features
# VGA port
# HDMI
# ethernet
# USB ports
# rubber pads
# price
# price
# heat output
# operation
# upgrade the ram
# price
# built-in mic
# Mac OS 10.9
# external microphones
# features
# shortcuts
# IOS system
# resolution
# fonts
# working
# features
# brightness
# adjustments
# CD/DVD player
# backlit keys
# "Home/End" type keys
# Microsoft Word
# memory
# speed
# flexibility
# speed
# simplicity
# design
# battery life
# display
# downloading apps
# screen
# software
# operating system
# slim plastic case
# recovery USB stick
# bass
# sound
# built quality
# performance
# Bluetooth interface
# Mac OS
# range
# start menu
# RAM
# touch screen
# games
# Photoshop
# "WLAN" card
# LAN device drivers
# built
# battery life
# OS
# Apple Customer Support
# Firewire 800
# USB3
# USB3
# MAC OS
# Windows 7
# iTunes
# security
# Mini form factor
# graphics stuff
# card reader
# remove the card
# spinning hard disk
# ssd drive
# HDMI
# firmware patch
# specs
# packing
# mother boards
# Mother Board
# graphics card
# 4G of RAM
# 8G of RAM
# performs
# virtual home schooling
# Cost
# operating system
# size
# weight
# mobility
# durability of the battery
# functions provided by the trackpad
# hardware
# software
# updates
# disc drive
# Screen
# res
# --------------------------------------------------------------------------------------------------------
